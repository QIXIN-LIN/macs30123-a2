# %%
import boto3
import dataset
import json

# %% [markdown]
# ## Step1: Setting Up RDS instance

# %%
rds = boto3.client('rds')
iam_client = boto3.client('iam')
role = iam_client.get_role(RoleName='LabRole')


try:
    response = rds.create_db_instance(
        DBInstanceIdentifier='relational-db',
        DBName='books',
        MasterUsername='username',
        MasterUserPassword='password',
        DBInstanceClass='db.t3.micro',
        Engine='MySQL',
        AllocatedStorage=5
    )
    print("RDS instance created successfully:", response)
    
    # Wait until DB is available to continue
    rds.get_waiter('db_instance_available').wait(DBInstanceIdentifier='relational-db')

    # Describe where DB is available and on what port
    db = rds.describe_db_instances()['DBInstances'][0]
    ENDPOINT = db['Endpoint']['Address']
    PORT = db['Endpoint']['Port']
    DBID = db['DBInstanceIdentifier']
    
    USERNAME = 'username'
    PASSWORD = 'password'
    
    print(DBID,
        "is available at", ENDPOINT,
        "on Port", PORT,
        )   
except Exception as e:
    print("Error creating RDS instance:", e)
# Out:
# RDS instance created successfully: {'DBInstance': {'DBInstanceIdentifier': 'relational-db', 'DBInstanceClass': 'db.t3.micro', 'Engine': 'mysql', 'DBInstanceStatus': 'creating', 'MasterUsername': 'username', 'DBName': 'books', 'AllocatedStorage': 5, 'PreferredBackupWindow': '06:09-06:39', 'BackupRetentionPeriod': 1, 'DBSecurityGroups': [], 'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0ebcfd71f93ad1599', 'Status': 'active'}], 'DBParameterGroups': [{'DBParameterGroupName': 'default.mysql8.0', 'ParameterApplyStatus': 'in-sync'}], 'DBSubnetGroup': {'DBSubnetGroupName': 'default', 'DBSubnetGroupDescription': 'default', 'VpcId': 'vpc-03fe4a0e60b95c95e', 'SubnetGroupStatus': 'Complete', 'Subnets': [{'SubnetIdentifier': 'subnet-06c5f1ed345b03ce5', 'SubnetAvailabilityZone': {'Name': 'us-east-1d'}, 'SubnetOutpost': {}, 'SubnetStatus': 'Active'}, {'SubnetIdentifier': 'subnet-023920fe191952e92', 'SubnetAvailabilityZone': {'Name': 'us-east-1a'}, 'SubnetOutpost': {}, 'SubnetStatus': 'Active'}, {'SubnetIdentifier': 'subnet-0536522c8ee1d89d8', 'SubnetAvailabilityZone': {'Name': 'us-east-1c'}, 'SubnetOutpost': {}, 'SubnetStatus': 'Active'}, {'SubnetIdentifier': 'subnet-0c8ae49e2e44ca7d7', 'SubnetAvailabilityZone': {'Name': 'us-east-1f'}, 'SubnetOutpost': {}, 'SubnetStatus': 'Active'}, {'SubnetIdentifier': 'subnet-069c93efc98606926', 'SubnetAvailabilityZone': {'Name': 'us-east-1e'}, 'SubnetOutpost': {}, 'SubnetStatus': 'Active'}, {'SubnetIdentifier': 'subnet-0f4af7fa41ba5c750', 'SubnetAvailabilityZone': {'Name': 'us-east-1b'}, 'SubnetOutpost': {}, 'SubnetStatus': 'Active'}]}, 'PreferredMaintenanceWindow': 'sat:07:10-sat:07:40', 'PendingModifiedValues': {'MasterUserPassword': '****'}, 'MultiAZ': False, 'EngineVersion': '8.0.35', 'AutoMinorVersionUpgrade': True, 'ReadReplicaDBInstanceIdentifiers': [], 'LicenseModel': 'general-public-license', 'OptionGroupMemberships': [{'OptionGroupName': 'default:mysql-8-0', 'Status': 'in-sync'}], 'PubliclyAccessible': True, 'StorageType': 'gp2', 'DbInstancePort': 0, 'StorageEncrypted': False, 'DbiResourceId': 'db-SHDV3QX3OLN25M4X3B4GVETWGM', 'CACertificateIdentifier': 'rds-ca-rsa2048-g1', 'DomainMemberships': [], 'CopyTagsToSnapshot': False, 'MonitoringInterval': 0, 'DBInstanceArn': 'arn:aws:rds:us-east-1:102168828713:db:relational-db', 'IAMDatabaseAuthenticationEnabled': False, 'PerformanceInsightsEnabled': False, 'DeletionProtection': False, 'AssociatedRoles': [], 'TagList': [], 'CustomerOwnedIpEnabled': False, 'BackupTarget': 'region', 'NetworkType': 'IPV4', 'StorageThroughput': 0, 'CertificateDetails': {'CAIdentifier': 'rds-ca-rsa2048-g1'}, 'DedicatedLogVolume': False}, 'ResponseMetadata': {'RequestId': 'd2384cf0-158b-4c1b-8f47-e0c81b11a177', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'd2384cf0-158b-4c1b-8f47-e0c81b11a177', 'strict-transport-security': 'max-age=31536000', 'content-type': 'text/xml', 'content-length': '4045', 'date': 'Thu, 02 May 2024 01:35:40 GMT'}, 'RetryAttempts': 0}}
# relational-db is available at relational-db.cfxyluhsb7bh.us-east-1.rds.amazonaws.com on Port 3306

# %%
# Get Name of Security Group
SGNAME = db['VpcSecurityGroups'][0]['VpcSecurityGroupId']

# Adjust Permissions for that security group so that we can access it on Port 3306
# If already SG is already adjusted, print this out
try:
    ec2 = boto3.client('ec2')
    data = ec2.authorize_security_group_ingress(
            GroupId=SGNAME,
            IpPermissions=[
                {'IpProtocol': 'tcp',
                 'FromPort': PORT,
                 'ToPort': PORT,
                 'IpRanges': [{'CidrIp': '0.0.0.0/0'}]}
            ]
    )
    print("Permissions adjusted successfully.")
    
except ec2.exceptions.ClientError as e:
    if e.response["Error"]["Code"] == 'InvalidPermission.Duplicate':
        print("Permissions already adjusted.")
    else:
        print(e)
# Out:
# Permissions already adjusted.

# %%
'''
import mysql.connector

# Connect to the MySQL database
conn =  mysql.connector.connect(host=ENDPOINT, 
                                user="username", 
                                passwd="password", 
                                port=PORT, 
                                database="books")
cur = conn.cursor()

# Create a new table
create_table_query = """
    CREATE TABLE IF NOT EXISTS books_table (
        book_id VARCHAR(255) PRIMARY KEY,
        title VARCHAR(255),
        price VARCHAR(255),
        stock VARCHAR(255),
        rating VARCHAR(255),
        img TEXT,
        description TEXT,
        UPC VARCHAR(255),
        Product_Type VARCHAR(255),
        Price_excl_tax VARCHAR(255),
        Price_incl_tax VARCHAR(255),
        Tax VARCHAR(255),
        Availability VARCHAR(255),
        Number_of_reviews INT
    );
    """
cur.execute(create_table_query)
print("Table 'books_table' created successfully.")
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import mysql.connector
#       3 # Connect to the MySQL database
# ----> 4 conn =  mysql.connector.connect(host=ENDPOINT,
#       5                                 user="username",
#       6                                 passwd="password",
#       7                                 port=PORT,
#       8                                 database="books")
#       9 cur = conn.cursor()
#      11 # Create a new table
#
# NameError: name 'ENDPOINT' is not defined

# %%
# Query the table

'''
USERNAME = 'username'
PASSWORD = 'password'

db_url = \
    'mysql+mysqlconnector://{}:{}@{}:{}/books'.format(
        USERNAME,
        PASSWORD,
        ENDPOINT,
        PORT)

db = dataset.connect(db_url)
'''

# %% [markdown]
# ## Step2: Get list of books to scrape & Get Sublists Considering Number of Concurrency Workers

# %%
import requests
import dataset
import re
from datetime import datetime
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

db_url = \
    'mysql+mysqlconnector://{}:{}@{}:{}/books'.format(
        USERNAME,
        PASSWORD,
        ENDPOINT,
        PORT)

db = dataset.connect(db_url)

base_url = 'http://books.toscrape.com/'

book_ids_urls = []

def scrape_books(html_soup, url):
    for book in html_soup.select('article.product_pod'):
        # For now, we'll only store the books url
        book_url = book.find('h3').find('a').get('href')
        book_url = urljoin(url, book_url)
        path = urlparse(book_url).path
        book_id = path.split('/')[2]
        book_ids_urls.append({"url": book_url, "book_id": book_id})
        # Upsert tries to update first and then insert instead
        db['books'].upsert({'book_id' : book_id,
                            'last_seen' : datetime.now()
                            }, ['book_id'])
        
        
# Scrape the pages in the catalogue
url = base_url
inp = input('Do you wish to re-scrape the catalogue (y/n)? ')
while True and inp == 'y':
    print('Now scraping page:', url)
    r = requests.get(url)
    html_soup = BeautifulSoup(r.text, 'html.parser')
    scrape_books(html_soup, url)
    # Is there a next page?
    next_a = html_soup.select('li.next > a')
    if not next_a or not next_a[0].get('href'):
        break
    url = urljoin(url, next_a[0].get('href'))
# Out:
# Now scraping page: http://books.toscrape.com/
# Now scraping page: http://books.toscrape.com/catalogue/page-2.html
# Now scraping page: http://books.toscrape.com/catalogue/page-3.html
# Now scraping page: http://books.toscrape.com/catalogue/page-4.html
# Now scraping page: http://books.toscrape.com/catalogue/page-5.html
# Now scraping page: http://books.toscrape.com/catalogue/page-6.html
# Now scraping page: http://books.toscrape.com/catalogue/page-7.html
# Now scraping page: http://books.toscrape.com/catalogue/page-8.html
# Now scraping page: http://books.toscrape.com/catalogue/page-9.html
# Now scraping page: http://books.toscrape.com/catalogue/page-10.html
# Now scraping page: http://books.toscrape.com/catalogue/page-11.html
# Now scraping page: http://books.toscrape.com/catalogue/page-12.html
# Now scraping page: http://books.toscrape.com/catalogue/page-13.html
# Now scraping page: http://books.toscrape.com/catalogue/page-14.html
# Now scraping page: http://books.toscrape.com/catalogue/page-15.html
# Now scraping page: http://books.toscrape.com/catalogue/page-16.html
# Now scraping page: http://books.toscrape.com/catalogue/page-17.html
# Now scraping page: http://books.toscrape.com/catalogue/page-18.html
# Now scraping page: http://books.toscrape.com/catalogue/page-19.html
# Now scraping page: http://books.toscrape.com/catalogue/page-20.html
# Now scraping page: http://books.toscrape.com/catalogue/page-21.html
# Now scraping page: http://books.toscrape.com/catalogue/page-22.html
# Now scraping page: http://books.toscrape.com/catalogue/page-23.html
# Now scraping page: http://books.toscrape.com/catalogue/page-24.html
# Now scraping page: http://books.toscrape.com/catalogue/page-25.html
# Now scraping page: http://books.toscrape.com/catalogue/page-26.html
# Now scraping page: http://books.toscrape.com/catalogue/page-27.html
# Now scraping page: http://books.toscrape.com/catalogue/page-28.html
# Now scraping page: http://books.toscrape.com/catalogue/page-29.html
# Now scraping page: http://books.toscrape.com/catalogue/page-30.html
# Now scraping page: http://books.toscrape.com/catalogue/page-31.html
# Now scraping page: http://books.toscrape.com/catalogue/page-32.html
# Now scraping page: http://books.toscrape.com/catalogue/page-33.html
# Now scraping page: http://books.toscrape.com/catalogue/page-34.html
# Now scraping page: http://books.toscrape.com/catalogue/page-35.html
# Now scraping page: http://books.toscrape.com/catalogue/page-36.html
# Now scraping page: http://books.toscrape.com/catalogue/page-37.html
# Now scraping page: http://books.toscrape.com/catalogue/page-38.html
# Now scraping page: http://books.toscrape.com/catalogue/page-39.html
# Now scraping page: http://books.toscrape.com/catalogue/page-40.html
# Now scraping page: http://books.toscrape.com/catalogue/page-41.html
# Now scraping page: http://books.toscrape.com/catalogue/page-42.html
# Now scraping page: http://books.toscrape.com/catalogue/page-43.html
# Now scraping page: http://books.toscrape.com/catalogue/page-44.html
# Now scraping page: http://books.toscrape.com/catalogue/page-45.html
# Now scraping page: http://books.toscrape.com/catalogue/page-46.html
# Now scraping page: http://books.toscrape.com/catalogue/page-47.html
# Now scraping page: http://books.toscrape.com/catalogue/page-48.html
# Now scraping page: http://books.toscrape.com/catalogue/page-49.html
# Now scraping page: http://books.toscrape.com/catalogue/page-50.html

# %% [markdown]
# ## Step3: Deploying Lambda Functions

# %%
import boto3

aws_lambda = boto3.client('lambda')


with open('q2-deployment-package.zip', 'rb') as f:
    lambda_zip = f.read()

# Define your environment variables here
env_variables = {
    'Variables': {
        'DB_ENDPOINT': ENDPOINT,
        'DB_USER': USERNAME,
        'DB_PASSWORD': PASSWORD,
        'DB_PORT': str(PORT), 
    }
}

try:
    response = aws_lambda.create_function(
        FunctionName='a2q2_lambda',
        Runtime='python3.9',
        Role=role['Role']['Arn'],
        Handler='lambda_function.lambda_handler',
        Code=dict(ZipFile=lambda_zip),
        Timeout=300,
        Environment=env_variables  # Add environment variables here
    )
    print("Lambda function created successfully:", response)
except aws_lambda.exceptions.ResourceConflictException:
    # Update the function code
    response = aws_lambda.update_function_code(
        FunctionName='a2q2_lambda',
        ZipFile=lambda_zip
    )
    print("Lambda function updated successfully:", response)

    # Optionally, update the environment variables if needed
    response = aws_lambda.update_function_configuration(
        FunctionName='a2q2_lambda',
        Environment=env_variables
    )
    print("Environment variables updated successfully:", response)

response = aws_lambda.put_function_concurrency(
    FunctionName='a2q2_lambda',
    ReservedConcurrentExecutions=10
)

print(response)
# Out:
# Lambda function created successfully: {'ResponseMetadata': {'RequestId': '2bc0a675-dcc6-45ec-8bbf-7ce502ba8188', 'HTTPStatusCode': 201, 'HTTPHeaders': {'date': 'Thu, 02 May 2024 02:05:21 GMT', 'content-type': 'application/json', 'content-length': '1475', 'connection': 'keep-alive', 'x-amzn-requestid': '2bc0a675-dcc6-45ec-8bbf-7ce502ba8188'}, 'RetryAttempts': 0}, 'FunctionName': 'a2q2_lambda', 'FunctionArn': 'arn:aws:lambda:us-east-1:102168828713:function:a2q2_lambda', 'Runtime': 'python3.9', 'Role': 'arn:aws:iam::102168828713:role/LabRole', 'Handler': 'lambda_function.lambda_handler', 'CodeSize': 45451548, 'Description': '', 'Timeout': 300, 'MemorySize': 128, 'LastModified': '2024-05-02T02:05:21.220+0000', 'CodeSha256': 'gAScAX+DgviNBhP/5H1Sa1oIVIWcwinkCzp8q2tqBL4=', 'Version': '$LATEST', 'Environment': {'Variables': {'DB_PORT': '3306', 'DB_ENDPOINT': 'relational-db.cfxyluhsb7bh.us-east-1.rds.amazonaws.com', 'DB_USER': 'username', 'DB_PASSWORD': 'password'}}, 'TracingConfig': {'Mode': 'PassThrough'}, 'RevisionId': '96d18e55-5880-40d2-ab89-53683e00d2d3', 'State': 'Pending', 'StateReason': 'The function is being created.', 'StateReasonCode': 'Creating', 'PackageType': 'Zip', 'Architectures': ['x86_64'], 'EphemeralStorage': {'Size': 512}, 'SnapStart': {'ApplyOn': 'None', 'OptimizationStatus': 'Off'}, 'RuntimeVersionConfig': {'RuntimeVersionArn': 'arn:aws:lambda:us-east-1::runtime:415294d499803f2ba2e75d2753b4523c4517c1c13e55d8ca19a44434f6cbb9a5'}, 'LoggingConfig': {'LogFormat': 'Text', 'LogGroup': '/aws/lambda/a2q2_lambda'}}
# {'ResponseMetadata': {'RequestId': 'fb9e84a2-88fa-4ea6-846d-ef905213047d', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 02 May 2024 02:05:21 GMT', 'content-type': 'application/json', 'content-length': '35', 'connection': 'keep-alive', 'x-amzn-requestid': 'fb9e84a2-88fa-4ea6-846d-ef905213047d'}, 'RetryAttempts': 0}, 'ReservedConcurrentExecutions': 10}

# %% [markdown]
# # Step4: Set Up Step Functions

# %%
import boto3
import json

def make_def(lambda_arn):
    definition = {
      "Comment": "Q2 State Machine",
      "StartAt": "Map",
      "States": {
        "Map": {
          "Type": "Map",
          "End": True,
          "MaxConcurrency": 10,
          "Iterator": {
            "StartAt": "Lambda Invoke",
            "States": {
              "Lambda Invoke": {
                "Type": "Task",
                "Resource": "arn:aws:states:::lambda:invoke",
                "OutputPath": "$.Payload",
                "Parameters": {
                  "Payload.$": "$",
                  "FunctionName": lambda_arn
                },
                "Retry": [
                  {
                    "ErrorEquals": [
                      "Lambda.ServiceException",
                      "Lambda.AWSLambdaException",
                      "Lambda.SdkClientException",
                      "Lambda.TooManyRequestsException",
                      "States.TaskFailed",
                      "Lambda.Unknown"                      
                    ],
                    "IntervalSeconds": 2,
                    "MaxAttempts": 6,
                    "BackoffRate": 2
                  }
                ],
                "End": True
              }
            }
          }
        }
      }
    }
    return definition

if __name__ == '__main__':
    iam = boto3.client('iam')
    sfn = boto3.client('stepfunctions')
    aws_lambda = boto3.client('lambda')
    role = iam.get_role(RoleName='LabRole')

    lambda_function_name = "a2q2_lambda"

    # Get Lambda Function ARN and Role ARN
    # Assumes Lambda function already exists
    lambda_arn = [f['FunctionArn']
                  for f in aws_lambda.list_functions()['Functions']
                  if f['FunctionName'] == lambda_function_name][0]
    
    # Throttle concurrent executions to 10
    response = aws_lambda.put_function_concurrency(
            FunctionName=lambda_function_name,
            ReservedConcurrentExecutions=10
        )

    sfn_function_name = "a2q2_stepfunctions"

    # Use Lambda ARN to create State Machine Definition
    sf_def = make_def(lambda_arn)

    # Create Step Function State Machine if doesn't already exist
    try:
        response = sfn.create_state_machine(
            name=sfn_function_name,
            definition=json.dumps(sf_def),
            roleArn=role['Role']['Arn'],
            type='EXPRESS' 
        )
    except sfn.exceptions.StateMachineAlreadyExists:
        response = sfn.list_state_machines()
        state_machine_arn = [sm['stateMachineArn'] 
                            for sm in response['stateMachines'] 
                            if sm['name'] == sfn_function_name][0]
        response = sfn.update_state_machine(
            stateMachineArn=state_machine_arn,
            definition=json.dumps(sf_def),
            roleArn=role['Role']['Arn']
        )

# %%
db_url = \
    'mysql+mysqlconnector://{}:{}@{}:{}/books'.format(
        USERNAME,
        PASSWORD,
        ENDPOINT,
        PORT)

db = dataset.connect(db_url)

# Get arn for Step Function state machine
response = sfn.list_state_machines()
state_machine_arn = [sm['stateMachineArn'] 
                     for sm in response['stateMachines'] 
                     if sm['name'] == sfn_function_name][0]

# generate test data to pass as input
# "Map" will automatically invoke a separate Lambda function
# to process each dictionary in the list (10 concurrently)
records = list(db['books'].find())
data = [{'book_id': record['book_id']} for record in records]
json_input = json.dumps(data)
# Out:
# [{'book_id': 'a-light-in-the-attic_1000'}, {'book_id': 'tipping-the-velvet_999'}, {'book_id': 'soumission_998'}, {'book_id': 'sharp-objects_997'}, {'book_id': 'sapiens-a-brief-history-of-humankind_996'}, {'book_id': 'the-requiem-red_995'}, {'book_id': 'the-dirty-little-secrets-of-getting-your-dream-job_994'}, {'book_id': 'the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993'}, {'book_id': 'the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992'}, {'book_id': 'the-black-maria_991'}, {'book_id': 'starving-hearts-triangular-trade-trilogy-1_990'}, {'book_id': 'shakespeares-sonnets_989'}, {'book_id': 'set-me-free_988'}, {'book_id': 'scott-pilgrims-precious-little-life-scott-pilgrim-1_987'}, {'book_id': 'rip-it-up-and-start-again_986'}, {'book_id': 'our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985'}, {'book_id': 'olio_984'}, {'book_id': 'mesaerion-the-best-science-fiction-stories-1800-1849_983'}, {'book_id': 'libertarianism-for-beginners_982'}, {'book_id': 'its-only-the-himalayas_981'}, {'book_id': 'in-her-wake_980'}, {'book_id': 'how-music-works_979'}, {'book_id': 'foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978'}, {'book_id': 'chase-me-paris-nights-2_977'}, {'book_id': 'black-dust_976'}, {'book_id': 'birdsong-a-story-in-pictures_975'}, {'book_id': 'americas-cradle-of-quarterbacks-western-pennsylvanias-football-factory-from-johnny-unitas-to-joe-montana_974'}, {'book_id': 'aladdin-and-his-wonderful-lamp_973'}, {'book_id': 'worlds-elsewhere-journeys-around-shakespeares-globe_972'}, {'book_id': 'wall-and-piece_971'}, {'book_id': 'the-four-agreements-a-practical-guide-to-personal-freedom_970'}, {'book_id': 'the-five-love-languages-how-to-express-heartfelt-commitment-to-your-mate_969'}, {'book_id': 'the-elephant-tree_968'}, {'book_id': 'the-bear-and-the-piano_967'}, {'book_id': 'sophies-world_966'}, {'book_id': 'penny-maybe_965'}, {'book_id': 'maude-1883-1993she-grew-up-with-the-country_964'}, {'book_id': 'in-a-dark-dark-wood_963'}, {'book_id': 'behind-closed-doors_962'}, {'book_id': 'you-cant-bury-them-all-poems_961'}, {'book_id': 'slow-states-of-collapse-poems_960'}, {'book_id': 'reasons-to-stay-alive_959'}, {'book_id': 'private-paris-private-10_958'}, {'book_id': 'higherselfie-wake-up-your-life-free-your-soul-find-your-tribe_957'}, {'book_id': 'without-borders-wanderlove-1_956'}, {'book_id': 'when-we-collided_955'}, {'book_id': 'we-love-you-charlie-freeman_954'}, {'book_id': 'untitled-collection-sabbath-poems-2014_953'}, {'book_id': 'unseen-city-the-majesty-of-pigeons-the-discreet-charm-of-snails-other-wonders-of-the-urban-wilderness_952'}, {'book_id': 'unicorn-tracks_951'}, {'book_id': 'unbound-how-eight-technologies-made-us-human-transformed-society-and-brought-our-world-to-the-brink_950'}, {'book_id': 'tsubasa-world-chronicle-2-tsubasa-world-chronicle-2_949'}, {'book_id': 'throwing-rocks-at-the-google-bus-how-growth-became-the-enemy-of-prosperity_948'}, {'book_id': 'this-one-summer_947'}, {'book_id': 'thirst_946'}, {'book_id': 'the-torch-is-passed-a-harding-family-story_945'}, {'book_id': 'the-secret-of-dreadwillow-carse_944'}, {'book_id': 'the-pioneer-woman-cooks-dinnertime-comfort-classics-freezer-food-16-minute-meals-and-other-delicious-ways-to-solve-supper_943'}, {'book_id': 'the-past-never-ends_942'}, {'book_id': 'the-natural-history-of-us-the-fine-art-of-pretending-2_941'}, {'book_id': 'the-nameless-city-the-nameless-city-1_940'}, {'book_id': 'the-murder-that-never-was-forensic-instincts-5_939'}, {'book_id': 'the-most-perfect-thing-inside-and-outside-a-birds-egg_938'}, {'book_id': 'the-mindfulness-and-acceptance-workbook-for-anxiety-a-guide-to-breaking-free-from-anxiety-phobias-and-worry-using-acceptance-and-commitment-therapy_937'}, {'book_id': 'the-life-changing-magic-of-tidying-up-the-jap ...

# %%
response = sfn.start_sync_execution(
    stateMachineArn=state_machine_arn,
    input=json_input
)
print(response)
# Out:
# {'executionArn': 'arn:aws:states:us-east-1:102168828713:express:a2q2_stepfunctions:813b4a42-a889-4911-baae-115849807818:e9ed57d3-22f4-432f-9bc0-9ea615f8115c', 'stateMachineArn': 'arn:aws:states:us-east-1:102168828713:stateMachine:a2q2_stepfunctions', 'name': '813b4a42-a889-4911-baae-115849807818', 'startDate': datetime.datetime(2024, 5, 1, 23, 29, 46, 198000, tzinfo=tzlocal()), 'stopDate': datetime.datetime(2024, 5, 1, 23, 30, 32, 910000, tzinfo=tzlocal()), 'status': 'SUCCEEDED', 'input': '[{"book_id": "a-light-in-the-attic_1000"}, {"book_id": "tipping-the-velvet_999"}, {"book_id": "soumission_998"}, {"book_id": "sharp-objects_997"}, {"book_id": "sapiens-a-brief-history-of-humankind_996"}, {"book_id": "the-requiem-red_995"}, {"book_id": "the-dirty-little-secrets-of-getting-your-dream-job_994"}, {"book_id": "the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993"}, {"book_id": "the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992"}, {"book_id": "the-black-maria_991"}, {"book_id": "starving-hearts-triangular-trade-trilogy-1_990"}, {"book_id": "shakespeares-sonnets_989"}, {"book_id": "set-me-free_988"}, {"book_id": "scott-pilgrims-precious-little-life-scott-pilgrim-1_987"}, {"book_id": "rip-it-up-and-start-again_986"}, {"book_id": "our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985"}, {"book_id": "olio_984"}, {"book_id": "mesaerion-the-best-science-fiction-stories-1800-1849_983"}, {"book_id": "libertarianism-for-beginners_982"}, {"book_id": "its-only-the-himalayas_981"}, {"book_id": "in-her-wake_980"}, {"book_id": "how-music-works_979"}, {"book_id": "foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978"}, {"book_id": "chase-me-paris-nights-2_977"}, {"book_id": "black-dust_976"}, {"book_id": "birdsong-a-story-in-pictures_975"}, {"book_id": "americas-cradle-of-quarterbacks-western-pennsylvanias-football-factory-from-johnny-unitas-to-joe-montana_974"}, {"book_id": "aladdin-and-his-wonderful-lamp_973"}, {"book_id": "worlds-elsewhere-journeys-around-shakespeares-globe_972"}, {"book_id": "wall-and-piece_971"}, {"book_id": "the-four-agreements-a-practical-guide-to-personal-freedom_970"}, {"book_id": "the-five-love-languages-how-to-express-heartfelt-commitment-to-your-mate_969"}, {"book_id": "the-elephant-tree_968"}, {"book_id": "the-bear-and-the-piano_967"}, {"book_id": "sophies-world_966"}, {"book_id": "penny-maybe_965"}, {"book_id": "maude-1883-1993she-grew-up-with-the-country_964"}, {"book_id": "in-a-dark-dark-wood_963"}, {"book_id": "behind-closed-doors_962"}, {"book_id": "you-cant-bury-them-all-poems_961"}, {"book_id": "slow-states-of-collapse-poems_960"}, {"book_id": "reasons-to-stay-alive_959"}, {"book_id": "private-paris-private-10_958"}, {"book_id": "higherselfie-wake-up-your-life-free-your-soul-find-your-tribe_957"}, {"book_id": "without-borders-wanderlove-1_956"}, {"book_id": "when-we-collided_955"}, {"book_id": "we-love-you-charlie-freeman_954"}, {"book_id": "untitled-collection-sabbath-poems-2014_953"}, {"book_id": "unseen-city-the-majesty-of-pigeons-the-discreet-charm-of-snails-other-wonders-of-the-urban-wilderness_952"}, {"book_id": "unicorn-tracks_951"}, {"book_id": "unbound-how-eight-technologies-made-us-human-transformed-society-and-brought-our-world-to-the-brink_950"}, {"book_id": "tsubasa-world-chronicle-2-tsubasa-world-chronicle-2_949"}, {"book_id": "throwing-rocks-at-the-google-bus-how-growth-became-the-enemy-of-prosperity_948"}, {"book_id": "this-one-summer_947"}, {"book_id": "thirst_946"}, {"book_id": "the-torch-is-passed-a-harding-family-story_945"}, {"book_id": "the-secret-of-dreadwillow-carse_944"}, {"book_id": "the-pioneer-woman-cooks-dinnertime-comfort-classics-freezer-food-16-minute-meals-and-other-delicious-ways-to-solve-supper_943"}, {"book_id": "the-past-never-ends_942"}, {"boo ...

# %%
db_url = \
    'mysql+mysqlconnector://{}:{}@{}:{}/books'.format(
        USERNAME,
        PASSWORD,
        ENDPOINT,
        PORT)

db = dataset.connect(db_url)

tables = db.tables
print("Tables in the database:", tables)
# Out:
# Tables in the database: ['book_info', 'books']

# %%
table = db['books']

# Fetch the first 10 records
records = table.find()
for record in records:
    print(record)
# Out:
# OrderedDict([('id', 1), ('book_id', 'a-light-in-the-attic_1000'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 2), ('book_id', 'tipping-the-velvet_999'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 3), ('book_id', 'soumission_998'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 4), ('book_id', 'sharp-objects_997'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 5), ('book_id', 'sapiens-a-brief-history-of-humankind_996'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 6), ('book_id', 'the-requiem-red_995'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 7), ('book_id', 'the-dirty-little-secrets-of-getting-your-dream-job_994'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 8), ('book_id', 'the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 9), ('book_id', 'the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 10), ('book_id', 'the-black-maria_991'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 11), ('book_id', 'starving-hearts-triangular-trade-trilogy-1_990'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 12), ('book_id', 'shakespeares-sonnets_989'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 13), ('book_id', 'set-me-free_988'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 14), ('book_id', 'scott-pilgrims-precious-little-life-scott-pilgrim-1_987'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 49))])
# OrderedDict([('id', 15), ('book_id', 'rip-it-up-and-start-again_986'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 16), ('book_id', 'our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 17), ('book_id', 'olio_984'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 18), ('book_id', 'mesaerion-the-best-science-fiction-stories-1800-1849_983'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 19), ('book_id', 'libertarianism-for-beginners_982'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 20), ('book_id', 'its-only-the-himalayas_981'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 21), ('book_id', 'in-her-wake_980'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 22), ('book_id', 'how-music-works_979'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 23), ('book_id', 'foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 24), ('book_id', 'chase-me-paris-nights-2_977'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 25), ('book_id', 'black-dust_976'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 26), ('book_id', 'birdsong-a-story-in-pictures_975'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 27), ('book_id', 'americas-cradle-of-quarterbacks-western-pennsylvanias-football-factory-from-johnny-unitas-to-joe-montana_974'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 28), ('book_id', 'aladdin-and-his-wonderful-lamp_973'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 29), ('book_id', 'worlds-elsewhere-journeys-around-shakespeares-globe_972'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 30), ('book_id', 'wall-and-piece_971'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 31), ('book_id', 'the-four-agreements-a-practical-guide-to-personal-freedom_970'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 32), ('book_id', 'the-five-love-languages-how-to-express-heartfelt-commitment-to-your-mate_969'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 33), ('book_id', 'the-elephant-tree_968'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 34), ('book_id', 'the-bear-and-the-piano_967'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 35), ('book_id', 'sophies-world_966'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 36), ('book_id', 'penny-maybe_965'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 37), ('book_id', 'maude-1883-1993she-grew-up-with-the-country_964'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 38), ('book_id', 'in-a-dark-dark-wood_963'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 39), ('book_id', 'behind-closed-doors_962'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 40), ('book_id', 'you-cant-bury-them-all-poems_961'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 41), ('book_id', 'slow-states-of-collapse-poems_960'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 50))])
# OrderedDict([('id', 42), ('book_id', 'reasons-to-stay-alive_959'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 43), ('book_id', 'private-paris-private-10_958'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 44), ('book_id', 'higherselfie-wake-up-your-life-free-your-soul-find-your-tribe_957'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 45), ('book_id', 'without-borders-wanderlove-1_956'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 46), ('book_id', 'when-we-collided_955'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 47), ('book_id', 'we-love-you-charlie-freeman_954'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 48), ('book_id', 'untitled-collection-sabbath-poems-2014_953'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 49), ('book_id', 'unseen-city-the-majesty-of-pigeons-the-discreet-charm-of-snails-other-wonders-of-the-urban-wilderness_952'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 50), ('book_id', 'unicorn-tracks_951'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 51), ('book_id', 'unbound-how-eight-technologies-made-us-human-transformed-society-and-brought-our-world-to-the-brink_950'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 52), ('book_id', 'tsubasa-world-chronicle-2-tsubasa-world-chronicle-2_949'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 53), ('book_id', 'throwing-rocks-at-the-google-bus-how-growth-became-the-enemy-of-prosperity_948'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 54), ('book_id', 'this-one-summer_947'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 55), ('book_id', 'thirst_946'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 56), ('book_id', 'the-torch-is-passed-a-harding-family-story_945'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 57), ('book_id', 'the-secret-of-dreadwillow-carse_944'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 58), ('book_id', 'the-pioneer-woman-cooks-dinnertime-comfort-classics-freezer-food-16-minute-meals-and-other-delicious-ways-to-solve-supper_943'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 59), ('book_id', 'the-past-never-ends_942'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 60), ('book_id', 'the-natural-history-of-us-the-fine-art-of-pretending-2_941'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 61), ('book_id', 'the-nameless-city-the-nameless-city-1_940'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 62), ('book_id', 'the-murder-that-never-was-forensic-instincts-5_939'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 63), ('book_id', 'the-most-perfect-thing-inside-and-outside-a-birds-egg_938'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 64), ('book_id', 'the-mindfulness-and-acceptance-workbook-for-anxiety-a-guide-to-breaking-free-from-anxiety-phobias-and-worry-using-acceptance-and-commitment-therapy_937'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 65), ('book_id', 'the-life-changing-magic-of-tidying-up-the-japanese-art-of-decluttering-and-organizing_936'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 66), ('book_id', 'the-inefficiency-assassin-time-management-tactics-for-working-smarter-not-longer_935'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 67), ('book_id', 'the-gutsy-girl-escapades-for-your-life-of-epic-adventure_934'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 68), ('book_id', 'the-electric-pencil-drawings-from-inside-state-hospital-no-3_933'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 51))])
# OrderedDict([('id', 69), ('book_id', 'the-death-of-humanity-and-the-case-for-life_932'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 70), ('book_id', 'the-bulletproof-diet-lose-up-to-a-pound-a-day-reclaim-energy-and-focus-upgrade-your-life_931'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 71), ('book_id', 'the-art-forger_930'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 72), ('book_id', 'the-age-of-genius-the-seventeenth-century-and-the-birth-of-the-modern-mind_929'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 73), ('book_id', 'the-activists-tao-te-ching-ancient-advice-for-a-modern-revolution_928'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 74), ('book_id', 'spark-joy-an-illustrated-master-class-on-the-art-of-organizing-and-tidying-up_927'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 75), ('book_id', 'soul-reader_926'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 76), ('book_id', 'security_925'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 77), ('book_id', 'saga-volume-6-saga-collected-editions-6_924'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 78), ('book_id', 'saga-volume-5-saga-collected-editions-5_923'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 79), ('book_id', 'reskilling-america-learning-to-labor-in-the-twenty-first-century_922'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 80), ('book_id', 'rat-queens-vol-3-demons-rat-queens-collected-editions-11-15_921'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 81), ('book_id', 'princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 82), ('book_id', 'princess-between-worlds-wide-awake-princess-5_919'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 83), ('book_id', 'pop-gun-war-volume-1-gift_918'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 84), ('book_id', 'political-suicide-missteps-peccadilloes-bad-calls-backroom-hijinx-sordid-pasts-rotten-breaks-and-just-plain-dumb-mistakes-in-the-annals-of-american-politics_917'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 85), ('book_id', 'patience_916'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 86), ('book_id', 'outcast-vol-1-a-darkness-surrounds-him-outcast-1_915'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 87), ('book_id', 'orange-the-complete-collection-1-orange-the-complete-collection-1_914'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 88), ('book_id', 'online-marketing-for-busy-authors-a-step-by-step-guide_913'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 89), ('book_id', 'on-a-midnight-clear_912'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 90), ('book_id', 'obsidian-lux-1_911'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 91), ('book_id', 'my-paris-kitchen-recipes-and-stories_910'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 92), ('book_id', 'masks-and-shadows_909'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 93), ('book_id', 'mama-tried-traditional-italian-cooking-for-the-screwed-crude-vegan-and-tattooed_908'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 94), ('book_id', 'lumberjanes-vol-2-friendship-to-the-max-lumberjanes-5-8_907'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 52))])
# OrderedDict([('id', 95), ('book_id', 'lumberjanes-vol-1-beware-the-kitten-holy-lumberjanes-1-4_906'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 96), ('book_id', 'lumberjanes-vol-3-a-terrible-plan-lumberjanes-9-12_905'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 97), ('book_id', 'layered-baking-building-and-styling-spectacular-cakes_904'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 98), ('book_id', 'judo-seven-steps-to-black-belt-an-introductory-guide-for-beginners_903'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 99), ('book_id', 'join_902'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 100), ('book_id', 'in-the-country-we-love-my-family-divided_901'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 101), ('book_id', 'immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 102), ('book_id', 'i-hate-fairyland-vol-1-madly-ever-after-i-hate-fairyland-compilations-1-5_899'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 103), ('book_id', 'i-am-a-hero-omnibus-volume-1_898'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 104), ('book_id', 'how-to-be-miserable-40-strategies-you-already-use_897'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 105), ('book_id', 'her-backup-boyfriend-the-sorensen-family-1_896'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 106), ('book_id', 'giant-days-vol-2-giant-days-5-8_895'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 107), ('book_id', 'forever-and-forever-the-courtship-of-henry-longfellow-and-fanny-appleton_894'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 108), ('book_id', 'first-and-first-five-boroughs-3_893'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 109), ('book_id', 'fifty-shades-darker-fifty-shades-2_892'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 110), ('book_id', 'everydata-the-misinformation-hidden-in-the-little-data-you-consume-every-day_891'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 111), ('book_id', 'dont-be-a-jerk-and-other-practical-advice-from-dogen-japans-greatest-zen-master_890'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 112), ('book_id', 'danganronpa-volume-1_889'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 113), ('book_id', 'crown-of-midnight-throne-of-glass-2_888'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 114), ('book_id', 'codename-baboushka-volume-1-the-conclave-of-death_887'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 115), ('book_id', 'camp-midnight_886'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 116), ('book_id', 'call-the-nurse-true-stories-of-a-country-nurse-on-a-scottish-isle_885'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 117), ('book_id', 'burning_884'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 118), ('book_id', 'bossypants_883'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 53))])
# OrderedDict([('id', 119), ('book_id', 'bitch-planet-vol-1-extraordinary-machine-bitch-planet-collected-editions_882'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 120), ('book_id', 'avatar-the-last-airbender-smoke-and-shadow-part-3-smoke-and-shadow-3_881'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 121), ('book_id', 'algorithms-to-live-by-the-computer-science-of-human-decisions_880'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 122), ('book_id', 'a-world-of-flavor-your-gluten-free-passport_879'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 123), ('book_id', 'a-piece-of-sky-a-grain-of-rice-a-memoir-in-four-meditations_878'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 124), ('book_id', 'a-murder-in-time_877'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 125), ('book_id', 'a-flight-of-arrows-the-pathfinders-2_876'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 126), ('book_id', 'a-fierce-and-subtle-poison_875'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 127), ('book_id', 'a-court-of-thorns-and-roses-a-court-of-thorns-and-roses-1_874'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 128), ('book_id', 'unqualified-how-god-uses-broken-people-to-do-big-things_873'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 129), ('book_id', 'you-are-what-you-love-the-spiritual-power-of-habit_872'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 130), ('book_id', 'william-shakespeares-star-wars-verily-a-new-hope-william-shakespeares-star-wars-4_871'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 131), ('book_id', 'tuesday-nights-in-1980_870'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 132), ('book_id', 'tracing-numbers-on-a-train_869'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 133), ('book_id', 'throne-of-glass-throne-of-glass-1_868'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 134), ('book_id', 'thomas-jefferson-and-the-tripoli-pirates-the-forgotten-war-that-changed-american-history_867'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 135), ('book_id', 'thirteen-reasons-why_866'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 136), ('book_id', 'the-white-cat-and-the-monk-a-retelling-of-the-poem-pangur-ban_865'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 137), ('book_id', 'the-wedding-dress_864'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 138), ('book_id', 'the-vacationers_863'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 139), ('book_id', 'the-third-wave-an-entrepreneurs-vision-of-the-future_862'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 140), ('book_id', 'the-stranger_861'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 54))])
# OrderedDict([('id', 141), ('book_id', 'the-shadow-hero-the-shadow-hero_860'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 142), ('book_id', 'the-secret-the-secret-1_859'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 143), ('book_id', 'the-regional-office-is-under-attack_858'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 144), ('book_id', 'the-psychopath-test-a-journey-through-the-madness-industry_857'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 145), ('book_id', 'the-project_856'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 146), ('book_id', 'the-power-of-now-a-guide-to-spiritual-enlightenment_855'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 147), ('book_id', 'the-omnivores-dilemma-a-natural-history-of-four-meals_854'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 148), ('book_id', 'the-nerdy-nummies-cookbook-sweet-treats-for-the-geek-in-all-of-us_853'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 149), ('book_id', 'the-murder-of-roger-ackroyd-hercule-poirot-4_852'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 150), ('book_id', 'the-mistake-off-campus-2_851'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 151), ('book_id', 'the-matchmakers-playbook-wingmen-inc-1_850'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 152), ('book_id', 'the-love-and-lemons-cookbook-an-apple-to-zucchini-celebration-of-impromptu-cooking_849'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 153), ('book_id', 'the-long-shadow-of-small-ghosts-murder-and-memory-in-an-american-city_848'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 154), ('book_id', 'the-kite-runner_847'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 155), ('book_id', 'the-house-by-the-lake_846'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 156), ('book_id', 'the-glittering-court-the-glittering-court-1_845'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 157), ('book_id', 'the-girl-on-the-train_844'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 158), ('book_id', 'the-genius-of-birds_843'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 159), ('book_id', 'the-emerald-mystery_842'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 160), ('book_id', 'the-cookies-cups-cookbook-125-sweet-savory-recipes-reminding-you-to-always-eat-dessert-first_841'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 161), ('book_id', 'the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 162), ('book_id', 'the-artists-way-a-spiritual-path-to-higher-creativity_839'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 163), ('book_id', 'the-art-of-war_838'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 164), ('book_id', 'the-argonauts_837'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 165), ('book_id', 'the-10-entrepreneur-live-your-startup-dream-without-quitting-your-day-job_836'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 166), ('book_id', 'suddenly-in-love-lake-haven-1_835'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 55))])
# OrderedDict([('id', 167), ('book_id', 'something-more-than-this_834'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 168), ('book_id', 'soft-apocalypse_833'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 169), ('book_id', 'so-youve-been-publicly-shamed_832'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 170), ('book_id', 'shoe-dog-a-memoir-by-the-creator-of-nike_831'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 171), ('book_id', 'shobu-samurai-project-aryoku-3_830'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 172), ('book_id', 'secrets-and-lace-fatal-hearts-1_829'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 173), ('book_id', 'scarlett-epstein-hates-it-here_828'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 174), ('book_id', 'romero-and-juliet-a-tragic-tale-of-love-and-zombies_827'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 175), ('book_id', 'redeeming-love_826'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 176), ('book_id', 'poses-for-artists-volume-1-dynamic-and-sitting-poses-an-essential-reference-for-figure-drawing-and-the-human-form_825'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 177), ('book_id', 'poems-that-make-grown-women-cry_824'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 178), ('book_id', 'nightingale-sing_823'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 179), ('book_id', 'night-sky-with-exit-wounds_822'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 180), ('book_id', 'mrs-houdini_821'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 181), ('book_id', 'modern-romance_820'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 182), ('book_id', 'miss-peregrines-home-for-peculiar-children-miss-peregrines-peculiar-children-1_819'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 183), ('book_id', 'louisa-the-extraordinary-life-of-mrs-adams_818'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 184), ('book_id', 'little-red_817'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 185), ('book_id', 'library-of-souls-miss-peregrines-peculiar-children-3_816'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 186), ('book_id', 'large-print-heart-of-the-pride_815'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 187), ('book_id', 'i-had-a-nice-time-and-other-lies-how-to-find-love-sht-like-that_814'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 188), ('book_id', 'hollow-city-miss-peregrines-peculiar-children-2_813'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 189), ('book_id', 'grumbles_812'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 190), ('book_id', 'full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 191), ('book_id', 'frostbite-vampire-academy-2_810'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 192), ('book_id', 'follow-you-home_809'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 193), ('book_id', 'first-steps-for-new-christians-print-edition_808'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 56))])
# OrderedDict([('id', 194), ('book_id', 'finders-keepers-bill-hodges-trilogy-2_807'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 195), ('book_id', 'fables-vol-1-legends-in-exile-fables-1_806'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 196), ('book_id', 'eureka-trivia-60_805'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 197), ('book_id', 'drive-the-surprising-truth-about-what-motivates-us_804'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 198), ('book_id', 'done-rubbed-out-reightman-bailey-1_803'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 199), ('book_id', 'doing-it-over-most-likely-to-1_802'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 200), ('book_id', 'deliciously-ella-every-day-quick-and-easy-recipes-for-gluten-free-snacks-packed-lunches-and-simple-meals_801'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 201), ('book_id', 'dark-notes_800'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 202), ('book_id', 'daring-greatly-how-the-courage-to-be-vulnerable-transforms-the-way-we-live-love-parent-and-lead_799'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 203), ('book_id', 'close-to-you_798'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 204), ('book_id', 'chasing-heaven-what-dying-taught-me-about-living_797'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 205), ('book_id', 'big-magic-creative-living-beyond-fear_796'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 206), ('book_id', 'becoming-wise-an-inquiry-into-the-mystery-and-art-of-living_795'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 207), ('book_id', 'beauty-restored-riley-family-legacy-novellas-3_794'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 208), ('book_id', 'batman-the-long-halloween-batman_793'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 209), ('book_id', 'batman-the-dark-knight-returns-batman_792'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 210), ('book_id', 'ayumis-violin_791'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 211), ('book_id', 'anonymous_790'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 212), ('book_id', 'amy-meets-the-saints-and-sages_789'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 213), ('book_id', 'amid-the-chaos_788'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 214), ('book_id', 'amatus_787'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 215), ('book_id', 'agnostic-a-spirited-manifesto_786'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 216), ('book_id', 'zealot-the-life-and-times-of-jesus-of-nazareth_785'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 217), ('book_id', 'you-you-1_784'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 57))])
# OrderedDict([('id', 218), ('book_id', 'wonder-woman-earth-one-volume-one-wonder-woman-earth-one-1_783'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 219), ('book_id', 'wild-swans_782'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 220), ('book_id', 'why-the-right-went-wrong-conservatism-from-goldwater-to-the-tea-party-and-beyond_781'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 221), ('book_id', 'whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 222), ('book_id', 'whats-it-like-in-space-stories-from-astronauts-whove-been-there_779'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 223), ('book_id', 'we-are-robin-vol-1-the-vigilante-business-we-are-robin-1_778'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 224), ('book_id', 'walt-disneys-alice-in-wonderland_777'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 225), ('book_id', 'v-for-vendetta-v-for-vendetta-complete_776'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 226), ('book_id', 'until-friday-night-the-field-party-1_775'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 227), ('book_id', 'unbroken-a-world-war-ii-story-of-survival-resilience-and-redemption_774'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 228), ('book_id', 'twenty-yawns_773'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 229), ('book_id', 'through-the-woods_772'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 230), ('book_id', 'this-is-where-it-ends_771'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 231), ('book_id', 'the-year-of-magical-thinking_770'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 232), ('book_id', 'the-wright-brothers_769'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 233), ('book_id', 'the-white-queen-the-cousins-war-1_768'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 234), ('book_id', 'the-wedding-pact-the-omalleys-2_767'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 235), ('book_id', 'the-time-keeper_766'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 236), ('book_id', 'the-testament-of-mary_765'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 237), ('book_id', 'the-star-touched-queen_764'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 238), ('book_id', 'the-songs-of-the-gods_763'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 239), ('book_id', 'the-song-of-achilles_762'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 240), ('book_id', 'the-rosie-project-don-tillman-1_761'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 241), ('book_id', 'the-power-of-habit-why-we-do-what-we-do-in-life-and-business_760'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 242), ('book_id', 'the-marriage-of-opposites_759'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 243), ('book_id', 'the-lucifer-effect-understanding-how-good-people-turn-evil_758'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 244), ('book_id', 'the-long-haul-diary-of-a-wimpy-kid-9_757'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 245), ('book_id', 'the-loney_756'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 58))])
# OrderedDict([('id', 246), ('book_id', 'the-literature-book-big-ideas-simply-explained_755'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 247), ('book_id', 'the-last-mile-amos-decker-2_754'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 248), ('book_id', 'the-immortal-life-of-henrietta-lacks_753'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 249), ('book_id', 'the-hidden-oracle-the-trials-of-apollo-1_752'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 250), ('book_id', 'the-help-yourself-cookbook-for-kids-60-easy-plant-based-recipes-kids-can-make-to-stay-healthy-and-save-the-earth_751'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 251), ('book_id', 'the-guilty-will-robie-4_750'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 252), ('book_id', 'the-first-hostage-jb-collins-2_749'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 253), ('book_id', 'the-dovekeepers_748'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 254), ('book_id', 'the-darkest-lie_747'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 255), ('book_id', 'the-bane-chronicles-the-bane-chronicles-1-11_746'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 256), ('book_id', 'the-bad-ass-librarians-of-timbuktu-and-their-race-to-save-the-worlds-most-precious-manuscripts_745'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 257), ('book_id', 'the-14th-colony-cotton-malone-11_744'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 258), ('book_id', 'that-darkness-gardiner-and-renner-1_743'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 259), ('book_id', 'tastes-like-fear-di-marnie-rome-3_742'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 260), ('book_id', 'take-me-with-you_741'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 261), ('book_id', 'swell-a-year-of-waves_740'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 262), ('book_id', 'superman-vol-1-before-truth-superman-by-gene-luen-yang-1_739'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 263), ('book_id', 'still-life-with-bread-crumbs_738'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 264), ('book_id', 'steve-jobs_737'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 265), ('book_id', 'sorting-the-beef-from-the-bull-the-science-of-food-fraud-forensics_736'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 266), ('book_id', 'someone-like-you-the-harrisons-2_735'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 267), ('book_id', 'so-cute-it-hurts-vol-6-so-cute-it-hurts-6_734'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 268), ('book_id', 'shtum_733'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 269), ('book_id', 'see-america-a-celebration-of-our-national-parks-treasured-sites_732'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 270), ('book_id', 'salt_731'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 29, 59))])
# OrderedDict([('id', 271), ('book_id', 'robin-war_730'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 272), ('book_id', 'red-hoodarsenal-vol-1-open-for-business-red-hoodarsenal-1_729'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 273), ('book_id', 'rain-fish_728'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 274), ('book_id', 'quarter-life-poetry-poems-for-the-young-broke-and-hangry_727'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 275), ('book_id', 'pet-sematary_726'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 276), ('book_id', 'overload-how-to-unplug-unwind-and-unleash-yourself-from-the-pressure-of-stress_725'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 277), ('book_id', 'once-was-a-time_724'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 278), ('book_id', 'old-school-diary-of-a-wimpy-kid-10_723'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 279), ('book_id', 'no-dream-is-too-high-life-lessons-from-a-man-who-walked-on-the-moon_722'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 280), ('book_id', 'naruto-3-in-1-edition-vol-14-includes-vols-40-41-42-naruto-omnibus-14_721'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 281), ('book_id', 'my-name-is-lucy-barton_720'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 282), ('book_id', 'my-mrs-brown_719'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 283), ('book_id', 'my-kind-of-crazy_718'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 284), ('book_id', 'mr-mercedes-bill-hodges-trilogy-1_717'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 285), ('book_id', 'more-than-music-chasing-the-dream-1_716'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 286), ('book_id', 'made-to-stick-why-some-ideas-survive-and-others-die_715'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 287), ('book_id', 'luis-paints-the-world_714'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 288), ('book_id', 'luckiest-girl-alive_713'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 289), ('book_id', 'lowriders-to-the-center-of-the-earth-lowriders-in-space-2_712'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 290), ('book_id', 'love-is-a-mix-tape-music-1_711'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 291), ('book_id', 'looking-for-lovely-collecting-the-moments-that-matter_710'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 292), ('book_id', 'living-leadership-by-insight-a-good-leader-achieves-a-great-leader-builds-monuments_709'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30))])
# OrderedDict([('id', 293), ('book_id', 'let-it-out-a-journey-through-journaling_708'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 294), ('book_id', 'lady-midnight-the-dark-artifices-1_707'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 295), ('book_id', 'its-all-easy-healthy-delicious-weeknight-meals-in-under-30-minutes_706'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 296), ('book_id', 'island-of-dragons-unwanteds-7_705'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 297), ('book_id', 'i-know-what-im-doing-and-other-lies-i-tell-myself-dispatches-from-a-life-under-construction_704'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 298), ('book_id', 'i-am-pilgrim-pilgrim-1_703'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 299), ('book_id', 'hyperbole-and-a-half-unfortunate-situations-flawed-coping-mechanisms-mayhem-and-other-things-that-happened_702'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 300), ('book_id', 'hush-hush-hush-hush-1_701'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 301), ('book_id', 'hold-your-breath-search-and-rescue-1_700'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 302), ('book_id', 'hamilton-the-revolution_699'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 303), ('book_id', 'greek-mythic-history_698'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 304), ('book_id', 'god-the-most-unpleasant-character-in-all-fiction_697'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 305), ('book_id', 'glory-over-everything-beyond-the-kitchen-house_696'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 306), ('book_id', 'feathers-displays-of-brilliant-plumage_695'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 307), ('book_id', 'far-away-places-on-the-brink-of-change-seven-continents-twenty-five-years_694'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 308), ('book_id', 'every-last-word_693'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 309), ('book_id', 'eligible-the-austen-project-4_692'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 310), ('book_id', 'el-deafo_691'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 1))])
# OrderedDict([('id', 311), ('book_id', 'eight-hundred-grapes_690'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 312), ('book_id', 'eaternity-more-than-150-deliciously-easy-vegan-recipes-for-a-long-healthy-satisfied-joyful-life_689'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 313), ('book_id', 'eat-fat-get-thin_688'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 314), ('book_id', 'dont-get-caught_687'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 315), ('book_id', 'doctor-sleep-the-shining-2_686'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 7))])
# OrderedDict([('id', 316), ('book_id', 'demigods-magicians-percy-and-annabeth-meet-the-kanes-percy-jackson-kane-chronicles-crossover-1-3_685'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 317), ('book_id', 'dear-mr-knightley_684'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 318), ('book_id', 'daily-fantasy-sports_683'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 319), ('book_id', 'crazy-love-overwhelmed-by-a-relentless-god_682'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 320), ('book_id', 'cometh-the-hour-the-clifton-chronicles-6_681'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 321), ('book_id', 'code-name-verity-code-name-verity-1_680'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 322), ('book_id', 'clockwork-angel-the-infernal-devices-1_679'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 323), ('book_id', 'city-of-glass-the-mortal-instruments-3_678'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 324), ('book_id', 'city-of-fallen-angels-the-mortal-instruments-4_677'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 325), ('book_id', 'city-of-bones-the-mortal-instruments-1_676'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 326), ('book_id', 'city-of-ashes-the-mortal-instruments-2_675'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 327), ('book_id', 'cell_674'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 328), ('book_id', 'catching-jordan-hundred-oaks_673'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 329), ('book_id', 'carry-on-warrior-thoughts-on-life-unarmed_672'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 330), ('book_id', 'carrie_671'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 331), ('book_id', 'buying-in-the-secret-dialogue-between-what-we-buy-and-who-we-are_670'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# OrderedDict([('id', 332), ('book_id', 'brain-on-fire-my-month-of-madness_669'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 2))])
# ...
# OrderedDict([('id', 882), ('book_id', 'and-then-there-were-none_119'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 24))])
# OrderedDict([('id', 883), ('book_id', 'a-walk-in-the-woods-rediscovering-america-on-the-appalachian-trail_118'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 24))])
# OrderedDict([('id', 884), ('book_id', 'a-visit-from-the-goon-squad_117'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 24))])
# OrderedDict([('id', 885), ('book_id', 'a-storm-of-swords-a-song-of-ice-and-fire-3_116'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 24))])
# OrderedDict([('id', 886), ('book_id', 'a-heartbreaking-work-of-staggering-genius_115'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 24))])
# OrderedDict([('id', 887), ('book_id', '8-keys-to-mental-health-through-exercise_114'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 888), ('book_id', 'girlboss_113'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 889), ('book_id', 'the-suffragettes-little-black-classics-96_112'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 890), ('book_id', 'the-sense-of-an-ending_111'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 891), ('book_id', 'the-sandman-vol-2-the-dolls-house-the-sandman-volumes-2_110'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 892), ('book_id', 'the-course-of-love_109'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 893), ('book_id', 'sugar-rush-offensive-line-2_108'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 894), ('book_id', 'saga-volume-2-saga-collected-editions-2_107'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 895), ('book_id', 'run-spot-run-the-ethics-of-keeping-pets_106'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 896), ('book_id', 'new-moon-twilight-2_105'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 897), ('book_id', 'life_104'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 898), ('book_id', 'kindle-paperwhite-users-guide_103'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 899), ('book_id', 'h-is-for-hawk_102'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 900), ('book_id', 'girl-online-on-tour-girl-online-2_101'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 901), ('book_id', 'fruits-basket-vol-2-fruits-basket-2_100'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 902), ('book_id', 'diary-of-a-minecraft-zombie-book-1-a-scare-of-a-dare-an-unofficial-minecraft-book_99'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 903), ('book_id', 'y-the-last-man-vol-1-unmanned-y-the-last-man-1_98'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 904), ('book_id', 'while-you-were-mine_97'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 905), ('book_id', 'where-lightning-strikes-bleeding-stars-3_96'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 906), ('book_id', 'when-im-gone_95'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 907), ('book_id', 'ways-of-seeing_94'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 908), ('book_id', 'vampire-knight-vol-1-vampire-knight-1_93'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 25))])
# OrderedDict([('id', 909), ('book_id', 'vampire-girl-vampire-girl-1_92'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 910), ('book_id', 'twenty-love-poems-and-a-song-of-despair_91'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 911), ('book_id', 'travels-with-charley-in-search-of-america_90'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 912), ('book_id', 'three-wishes-river-of-time-california-1_89'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 913), ('book_id', 'this-one-moment-pushing-limits-1_88'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 914), ('book_id', 'the-zombie-room_87'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 915), ('book_id', 'the-wicked-the-divine-vol-1-the-faust-act-the-wicked-the-divine_86'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 916), ('book_id', 'the-tumor_85'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 917), ('book_id', 'the-story-of-hong-gildong_84'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 918), ('book_id', 'the-silent-wife_83'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 919), ('book_id', 'the-silent-twin-detective-jennifer-knight-3_82'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 920), ('book_id', 'the-selfish-gene_81'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 921), ('book_id', 'the-secret-healer_80'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 922), ('book_id', 'the-sandman-vol-1-preludes-and-nocturnes-the-sandman-volumes-1_79'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 923), ('book_id', 'the-republic_78'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 924), ('book_id', 'the-odyssey_77'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 925), ('book_id', 'the-no-1-ladies-detective-agency-no-1-ladies-detective-agency-1_76'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 926), ('book_id', 'the-nicomachean-ethics_75'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 927), ('book_id', 'the-name-of-the-wind-the-kingkiller-chronicle-1_74'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 928), ('book_id', 'the-mirror-the-maze-the-wrath-and-the-dawn-15_73'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 929), ('book_id', 'the-little-prince_72'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 930), ('book_id', 'the-light-of-the-fireflies_71'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 931), ('book_id', 'the-last-girl-the-dominion-trilogy-1_70'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 26))])
# OrderedDict([('id', 932), ('book_id', 'the-iliad_69'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 933), ('book_id', 'the-hook-up-game-on-1_68'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 934), ('book_id', 'the-haters_67'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 935), ('book_id', 'the-girl-you-lost_66'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 936), ('book_id', 'the-girl-in-the-ice-dci-erika-foster-1_65'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 937), ('book_id', 'the-end-of-the-jesus-era-an-investigation-1_64'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 938), ('book_id', 'the-edge-of-reason-bridget-jones-2_63'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 939), ('book_id', 'the-complete-maus-maus-1-2_62'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 940), ('book_id', 'the-communist-manifesto_61'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 941), ('book_id', 'the-bhagavad-gita_60'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 942), ('book_id', 'the-bette-davis-club_59'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 943), ('book_id', 'the-art-of-not-breathing_58'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 944), ('book_id', 'taking-shots-assassins-1_57'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 945), ('book_id', 'starlark_56'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 946), ('book_id', 'skip-beat-vol-01-skip-beat-1_55'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 947), ('book_id', 'sister-sable-the-mad-queen-1_54'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 948), ('book_id', 'shatter-me-shatter-me-1_53'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 949), ('book_id', 'shameless_52'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 950), ('book_id', 'shadow-rites-jane-yellowrock-10_51'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 951), ('book_id', 'settling-the-score-the-summer-games-1_50'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 952), ('book_id', 'sense-and-sensibility_49'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 953), ('book_id', 'saga-volume-1-saga-collected-editions-1_48'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 954), ('book_id', 'rhythm-chord-malykhin_47'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 27))])
# OrderedDict([('id', 955), ('book_id', 'rat-queens-vol-1-sass-sorcery-rat-queens-collected-editions-1-5_46'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 956), ('book_id', 'paradise-lost-paradise-1_45'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 957), ('book_id', 'paper-girls-vol-1-paper-girls-1-5_44'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 958), ('book_id', 'ouran-high-school-host-club-vol-1-ouran-high-school-host-club-1_43'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 959), ('book_id', 'origins-alphas-05_42'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 960), ('book_id', 'one-second-seven-7_41'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 961), ('book_id', 'on-the-road-duluoz-legend_40'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 962), ('book_id', 'old-records-never-die-one-mans-quest-for-his-vinyl-and-his-past_39'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 963), ('book_id', 'off-sides-off-1_38'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 964), ('book_id', 'of-mice-and-men_37'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 33))])
# OrderedDict([('id', 965), ('book_id', 'myriad-prentor-1_36'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 966), ('book_id', 'my-perfect-mistake-over-the-top-1_35'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 967), ('book_id', 'ms-marvel-vol-1-no-normal-ms-marvel-2014-2015-1_34'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 968), ('book_id', 'meditations_33'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 969), ('book_id', 'matilda_32'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 970), ('book_id', 'lost-among-the-living_31'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 971), ('book_id', 'lord-of-the-flies_30'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 972), ('book_id', 'listen-to-me-fusion-1_29'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 973), ('book_id', 'kitchens-of-the-great-midwest_28'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 974), ('book_id', 'jane-eyre_27'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 975), ('book_id', 'imperfect-harmony_26'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 976), ('book_id', 'icing-aces-hockey-2_25'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 977), ('book_id', 'hawkeye-vol-1-my-life-as-a-weapon-hawkeye-1_24'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 978), ('book_id', 'having-the-barbarians-baby-ice-planet-barbarians-75_23'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 979), ('book_id', 'giant-days-vol-1-giant-days-1-4_22'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 980), ('book_id', 'fruits-basket-vol-1-fruits-basket-1_21'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 981), ('book_id', 'frankenstein_20'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 28))])
# OrderedDict([('id', 982), ('book_id', 'forever-rockers-the-rocker-12_19'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 983), ('book_id', 'fighting-fate-fighting-6_18'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 984), ('book_id', 'emma_17'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 985), ('book_id', 'eat-pray-love_16'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 986), ('book_id', 'deep-under-walker-security-1_15'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 987), ('book_id', 'choosing-our-religion-the-spiritual-lives-of-americas-nones_14'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 988), ('book_id', 'charlie-and-the-chocolate-factory-charlie-bucket-1_13'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 989), ('book_id', 'charitys-cross-charles-towne-belles-4_12'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 990), ('book_id', 'bright-lines_11'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 991), ('book_id', 'bridget-joness-diary-bridget-jones-1_10'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 992), ('book_id', 'bounty-colorado-mountain-7_9'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 993), ('book_id', 'blood-defense-samantha-brinkman-1_8'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 994), ('book_id', 'bleach-vol-1-strawberry-and-the-soul-reapers-bleach-1_7'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 995), ('book_id', 'beyond-good-and-evil_6'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 996), ('book_id', 'alice-in-wonderland-alices-adventures-in-wonderland-1_5'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 997), ('book_id', 'ajin-demi-human-volume-1-ajin-demi-human-1_4'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 998), ('book_id', 'a-spys-devotion-the-regency-spies-of-london-1_3'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 999), ('book_id', '1st-to-die-womens-murder-club-1_2'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])
# OrderedDict([('id', 1000), ('book_id', '1000-places-to-see-before-you-die_1'), ('last_seen', datetime.datetime(2024, 5, 2, 4, 30, 29))])

# %%
'''
# Synchronous Execution
response = sfn.start_sync_execution(
    stateMachineArn=state_machine_arn,
    name='sync_test',
    input=json.dumps(data)
)

print(response['output'])
'''
# Out:
# [null,null,null,null,null]

# %%
'''
# Async; perhaps writing results to db and don't need to wait for execution to finish before moving on with code
response = sfn.start_execution(
    stateMachineArn=state_machine_arn,
    name='async_test',
    input=json.dumps(data)
)
'''


print(response) # no results returned for async option
# Can go into logs in Cloud Watch and see execution results (Express SF workflow)
# Note that Standard Step Function workflow allows us to audit results via Boto3)
